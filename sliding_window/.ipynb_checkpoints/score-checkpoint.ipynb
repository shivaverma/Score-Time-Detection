# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("total training data: %d" %len(x_train))
print("total testing data: %d" %len(x_test))
print("dimensions of image:",(x_train[0]).shape)
# Out:
# total training data: 60000
# total testing data: 10000
# dimensions of image: (28, 28)

# %%
print(x_train[0][6])

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)
# Out:
# [  0   0   0   0   0   0   0   0  30  36  94 154 170 253 253 253 253 253
#  225 172 253 242 195  64   0   0   0   0]

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))

# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Dropout(rate=.1))

model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))

# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Dropout(rate=.1))

model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.2623 - acc: 0.9231
# Epoch 2/3
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1079 - acc: 0.9671
# Epoch 3/3
# 60000/60000 [==============================] - 6s 102us/step - loss: 0.0749 - acc: 0.9761

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print("\nval loss:", val_loss, "\nval_acc:", val_acc)
# Out:
# 10000/10000 [==============================] - 0s 50us/step
#
# val loss: 0.09147961449613795
# val_acc: 0.9703

# %%
# predict = model.predict([x_test])

# %%
image = [cv2.imread('digit/four.jpg', cv2.IMREAD_GRAYSCALE,),]
plt.imshow(image[0])
print("image shape:",image[0].shape)
print("greyscale image:")
# Out:
# image shape: (720, 720)
# greyscale image:

# %%
image[0] = cv2.resize(image[0], (28, 28)) 
image[0] = cv2.normalize(image[0], None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
print("image shape:",image[0].shape)
plt.imshow(image[0])
# Out:
# image shape: (28, 28)

# %%
predict = model.predict([image])
print(predict)
print("Predicted Number:", np.argmax(predict))
# Out:
# [[9.9976927e-01 4.7056154e-17 5.0701390e-17 1.6942806e-07 9.1628983e-37
#   2.3040117e-04 1.7555105e-07 7.0725574e-12 8.8606643e-11 4.1346641e-13]]
# Predicted Number: 0
